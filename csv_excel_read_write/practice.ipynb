# %%
import pandas as pd
df = pd.read_csv('./nyc_weather.csv')
df
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# ...

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
int(df['Temperature'].max())
# Out:
# 50

# %%
float(df['DewPoint'].mean())
# Out:
# 17.838709677419356

# %%
float(df['Temperature'].std())
# Out:
# 7.639315400279416

# %%
df[['Temperature','Humidity']]
# Out:
#     Temperature  Humidity
# 0            38        52
# 1            36        46
# 2            40        47
# 3            25        44
# 4            20        41
# 5            33        35
# 6            39        33
# 7            39        64
# 8            44        77
# 9            50        71
# 10           33        37
# 11           35        53
# 12           26        42
# 13           30        47
# 14           43        62
# 15           47        70
# 16           36        66
# 17           25        53
# 18           22        42
# 19           32        49
# 20           31        45
# 21           26        41
# 22           26        78
# 23           28        53
# 24           34        54
# 25           43        56
# 26           41        45
# 27           37        51
# 28           36        50
# 29           34        46
# 30           46        52

# %%
df[['Temperature','Humidity']][df['Temperature']==df['Temperature'].max()]
# Out:
#    Temperature  Humidity
# 9           50        71

# %%
df.set_index('EST',inplace=True)

# %%
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
df.loc['1/10/2016']
# Out:
# Temperature                50
# DewPoint                   46
# Humidity                   71
# Sea Level PressureIn    29.59
# VisibilityMiles             4
# WindSpeedMPH              NaN
# PrecipitationIn           1.8
# CloudCover                  7
# Events                   Rain
# WindDirDegrees            109
# Name: 1/10/2016, dtype: object

# %%
df = pd.read_csv('./nyc_weather.csv',nrows=3)
df
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8                0           5     NaN
# 1               10             7                0           3     NaN
# 2               10             8                0           1     NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df.to_csv('./new.csv',index=False)

# %%
df2 = pd.read_csv('./new.csv')
df2
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  Events  \
# 0               10             8                0           5     NaN
# 1               10             7                0           3     NaN
# 2               10             8                0           1     NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df3 = pd.read_excel('./stock_data.xlsx')
print(df3)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata
#    Unnamed: 0 tickers            eps  revenue price         people
# 0           0   GOOGL          27.82       87   845     larry page
# 1           1     WMT           4.61      484    65           n.a.
# 2           2    MSFT             -1       85    64     bill gates
# 3           3    RIL   not available       50  1023  mukesh ambani
# 4           4    TATA            5.6       -1  n.a.     ratan tata

# %%
df3.to_excel('./new.xlsx',index=False)

# %%
df4=pd.read_excel('./new.xlsx')
df4
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('./weather_stocks.xlsx') as writer:
    df_stocks.to_excel(writer,sheet_name="stocks",index=None)
    df_weather.to_excel(writer,sheet_name="weather",index=None)

# %%
df5 = pd.read_excel('./weather_stocks.xlsx',sheet_name="stocks")
df5
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 2  1/3/2017           28   Snow

# %%
df6 = pd.read_excel('./weather_stocks.xlsx',sheet_name="weather")
df6
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 2  1/3/2017           28   Snow
